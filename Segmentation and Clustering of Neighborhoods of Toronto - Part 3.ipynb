# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# Installing libraries and scrapping data from the Wikipedia Page

# %%
import pandas as pd 
import requests 
import numpy as np
from bs4 import BeautifulSoup

import folium

from sklearn.cluster import KMeans

import matplotlib.cm as cm
import matplotlib.colors as colors


req = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M") 
soup = BeautifulSoup(req.content,'html.parser')

# %% [markdown]
# Creating a data frame from the above table

# %%
table_contents=[]
table=soup.find('table')
df = pd.read_html(str(table))[0]
df.head()
# Out:
#                                                    0                1  \
# 0                                    M1ANot assigned  M2ANot assigned
# 1                    M1BScarborough(Malvern / Rouge)  M2BNot assigned
# 2  M1CScarborough(Rouge Hill / Port Union / Highl...  M2CNot assigned
# 3  M1EScarborough(Guildwood / Morningside / West ...  M2ENot assigned
# 4                             M1GScarborough(Woburn)  M2GNot assigned
#
#                                                 2  \
# 0                        M3ANorth York(Parkwoods)
# 1                   M3BNorth York(Don Mills)North
# 2  M3CNorth York(Don Mills)South(Flemingdon Park)
# 3                                 M3ENot assigned
# 4                                 M3GNot assigned
#
#                                                 3  \
# 0                 M4ANorth York(Victoria Village)
# 1  M4BEast York(Parkview Hill / Woodbine Gardens)
# 2                  M4CEast York(Woodbine Heights)
# ...

# %% [markdown]
# Removing all entries where borough is not assigned and modify the table to have 3 columns

# %%
for row in table.findAll('td'):
    cell = {}
    if row.span.text=='Not assigned':
        pass
    else:
        cell['PostalCode'] = row.p.text[:3]
        cell['Borough'] = (row.span.text).split('(')[0]
        cell['Neighborhood'] = (((((row.span.text).split('(')[1]).strip(')')).replace(' /',',')).replace(')',' ')).strip(' ')
        table_contents.append(cell)

#print(table_contents)

# %% [markdown]
# Modify the table

# %%
df=pd.DataFrame(table_contents)
df.head(10)
# Out:
#   PostalCode           Borough                      Neighborhood
# 0        M3A        North York                         Parkwoods
# 1        M4A        North York                  Victoria Village
# 2        M5A  Downtown Toronto         Regent Park, Harbourfront
# 3        M6A        North York  Lawrence Manor, Lawrence Heights
# 4        M7A      Queen's Park     Ontario Provincial Government
# 5        M9A         Etobicoke                  Islington Avenue
# 6        M1B       Scarborough                    Malvern, Rouge
# 7        M3B        North York                   Don Mills North
# 8        M4B         East York   Parkview Hill, Woodbine Gardens
# 9        M5B  Downtown Toronto          Garden District, Ryerson

# %% [markdown]
# Printing the number of rows in the dataframe

# %%
print(df.shape)
# Out:
# (103, 3)

# %%
df_geo_coordinates = pd.read_csv("./Geospatial_Coordinates.csv")
df_geo_coordinates.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
new_df = pd.merge(df, df_geo_coordinates, how='left', left_on='PostalCode', right_on='Postal Code')
new_df.drop('Postal Code', axis=1, inplace=True)
new_df.head()
# Out:
#   PostalCode           Borough                      Neighborhood   Latitude  \
# 0        M3A        North York                         Parkwoods  43.753259
# 1        M4A        North York                  Victoria Village  43.725882
# 2        M5A  Downtown Toronto         Regent Park, Harbourfront  43.654260
# 3        M6A        North York  Lawrence Manor, Lawrence Heights  43.718518
# 4        M7A      Queen's Park     Ontario Provincial Government  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %%
new_df.shape
# Out:
# (103, 5)

# %% [markdown]
# Choosing only the boroughs with 'Toronto' in it

# %%
toronto_new_data=new_df[new_df['Borough'].str.contains('Toronto')]
toronto_new_data.head()
# Out:
#    PostalCode           Borough               Neighborhood   Latitude  \
# 2         M5A  Downtown Toronto  Regent Park, Harbourfront  43.654260
# 9         M5B  Downtown Toronto   Garden District, Ryerson  43.657162
# 15        M5C  Downtown Toronto             St. James Town  43.651494
# 19        M4E      East Toronto                The Beaches  43.676357
# 20        M5E  Downtown Toronto                Berczy Park  43.644771
#
#     Longitude
# 2  -79.360636
# 9  -79.378937
# 15 -79.375418
# 19 -79.293031
# 20 -79.373306

# %% [markdown]
# Importing Libraries

# %%
# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
#
# Libraries imported.

# %% [markdown]
# Create map of Toronto using latitude and longitude values

# %%
address = "Toronto, ON"

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
lat = location.latitude
long = location.longitude
print('The coordinates of Toronto are: {}, {}.'.format(lat, long))
map_toronto = folium.Map(location=[lat, long], zoom_start=10)
map_toronto
# Out:
# The coordinates of Toronto are: 43.6534817, -79.3839347.
# ...

# %% [markdown]
# Adding markers to the map

# %%
for lat, lng, label in zip(toronto_new_data['Latitude'], toronto_new_data['Longitude'], toronto_new_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %%
CLIENT_ID = '4I4K4JX2LWBCWOM23QUHKJYPNRPUZVUJG4XM144QVZYRBJIG' # your Foursquare ID
CLIENT_SECRET = 'F3GSQDQ3ECVY5SL5UN2GRCO21HHD0MC3TVILBN2KWEHKSK4R' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

#print('Your credentails:')
#print('CLIENT_ID: ' + CLIENT_ID)
#print('CLIENT_SECRET:' + CLIENT_SECRET)

# %% [raw]
# Get details about a Neighborhood

# %%
neigh_name = toronto_new_data.loc[2,'Neighborhood']
neigh_lat = toronto_new_data.loc[2, 'Latitude']
neigh_long = toronto_new_data.loc[2, "Longitude"]
print('Latitude and longitude values of {} are {}, {}.'.format(neigh_name, neigh_lat, neigh_long))
# Out:
# Latitude and longitude values of Regent Park, Harbourfront are 43.6542599, -79.3606359.

# %% [raw]
# Find out the top 100 venues that are in the above area within 500 metres radius

# %%
LIMIT = 100 
radius = 500 
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neigh_lat, 
    neigh_long, 
    radius, 
    LIMIT)

# get the result to a json file
results = requests.get(url).json()

# %% [markdown]
# Create a function that extracts the category of the venue and then put it in a pandas dataframe

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# Collect all venues

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head(10)
# Out:
# <ipython-input-17-53c7dde730be>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   nearby_venues = json_normalize(venues) # flatten JSON
#                                name            categories        lat  \
# 0                     Tandem Coffee           Coffee Shop  43.653559
# 1                  Roselle Desserts                Bakery  43.653447
# 2            Cooper Koo Family YMCA   Distribution Center  43.653249
# 3                    Impact Kitchen            Restaurant  43.656369
# 4               Body Blitz Spa East                   Spa  43.654735
# 5          Dominion Pub and Kitchen                   Pub  43.656919
# 6                   Corktown Common                  Park  43.655618
# 7                The Extension Room  Gym / Fitness Center  43.653313
# 8  The Distillery Historic District         Historic Site  43.650244
# 9               SOMA chocolatemaker        Chocolate Shop  43.650622
#
#          lng
# ...

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 45 venues were returned by Foursquare.

# %% [markdown]
# Explore the Neighborhoods of Toronto

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
 #       print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()['response']['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names = toronto_new_data['Neighborhood'], latitudes = toronto_new_data['Latitude'], longitudes=toronto_new_data['Longitude'])
print(toronto_venues.shape)
toronto_venues.head()
toronto_venues.groupby('Neighborhood').count()
# Out:
# (1620, 7)
#                                                     Neighborhood Latitude  \
# Neighborhood
# Berczy Park                                                            61
# Brockton, Parkdale Village, Exhibition Place                           23
# CN Tower, King and Spadina, Railway Lands, Harb...                     18
# Central Bay Street                                                     65
# Christie                                                               15
# Church and Wellesley                                                   79
# Commerce Court, Victoria Hotel                                        100
# Davisville                                                             37
# Davisville North                                                        8
# Dufferin, Dovercourt Village                                           17
# Enclave of M4L                                                         17
# ...

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 242 uniques categories.

# %% [markdown]
# Analyze each Neighborhood

# %%
#one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

#add neighborhood column back to dataframe 
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood']

#move neighborhood to first column
temp_col = [toronto_onehot.columns[-1]]+ list(toronto_onehot.columns[:-1])
toronto_onehot=toronto_onehot[temp_col]
toronto_onehot.head()
toronto_onehot.shape
# Out:
# (1620, 242)

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped
# Out:
#                                          Neighborhood  Yoga Studio  \
# 0                                         Berczy Park     0.000000
# 1        Brockton, Parkdale Village, Exhibition Place     0.000000
# 2   CN Tower, King and Spadina, Railway Lands, Har...     0.000000
# 3                                  Central Bay Street     0.015385
# 4                                            Christie     0.000000
# 5                                Church and Wellesley     0.025316
# 6                      Commerce Court, Victoria Hotel     0.010000
# 7                                          Davisville     0.000000
# 8                                    Davisville North     0.000000
# 9                        Dufferin, Dovercourt Village     0.000000
# 10                                     Enclave of M4L     0.058824
# 11                                     Enclave of M5E     0.010204
# 12             First Canadian Place, Underground city     0.000000
# ...

# %% [markdown]
# Print the top 5 most common venues in each neighborhood

# %%
num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Berczy Park----
#          venue  freq
# 0  Coffee Shop  0.07
# 1       Bakery  0.05
# 2     Pharmacy  0.03
# 3   Restaurant  0.03
# 4     Beer Bar  0.03
#
#
# ----Brockton, Parkdale Village, Exhibition Place----
#             venue  freq
# 0            Café  0.13
# 1  Breakfast Spot  0.09
# 2          Bakery  0.09
# 3     Coffee Shop  0.09
# 4    Climbing Gym  0.04
#
#
# ----CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport----
#               venue  freq
# 0   Airport Service  0.17
# 1    Airport Lounge  0.11
# 2  Airport Terminal  0.11
# 3   Harbor / Marina  0.06
# 4               Bar  0.06
#
#
# ----Central Bay Street----
#              venue  freq
# 0      Coffee Shop  0.17
# 1             Café  0.06
# 2   Sandwich Place  0.05
# 3  Bubble Tea Shop  0.03
# 4             Bank  0.03
#
#
# ----Christie----
#                 venue  freq
# 0       Grocery Store  0.27
# 1                Café  0.20
# ...

# %% [markdown]
# Putting everything in a pandas dataframe

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Lets create a dataframe and display top 10 values for each dataframe

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                        Berczy Park           Coffee Shop
# 1       Brockton, Parkdale Village, Exhibition Place                  Café
# 2  CN Tower, King and Spadina, Railway Lands, Har...       Airport Service
# 3                                 Central Bay Street           Coffee Shop
# 4                                           Christie         Grocery Store
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                Bakery        Farmers Market           Cheese Shop
# 1                Bakery           Coffee Shop        Breakfast Spot
# 2        Airport Lounge      Airport Terminal       Harbor / Marina
# 3                  Café        Sandwich Place      Department Store
# 4                  Café                  Park           Coffee Shop
#
#   5th Most Common Venue  6th Most Common Venue 7th Most Common Venue  \
# ...

# %% [markdown]
# Clustering Neighborhood

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2])

# %% [markdown]
# Create a new dataframe that includes the cluster and top 10 venues for each neighborhood

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = toronto_new_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head() # check the last columns!
# Out:
#    PostalCode           Borough               Neighborhood   Latitude  \
# 2         M5A  Downtown Toronto  Regent Park, Harbourfront  43.654260
# 9         M5B  Downtown Toronto   Garden District, Ryerson  43.657162
# 15        M5C  Downtown Toronto             St. James Town  43.651494
# 19        M4E      East Toronto                The Beaches  43.676357
# 20        M5E  Downtown Toronto                Berczy Park  43.644771
#
#     Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 2  -79.360636               2           Coffee Shop                   Pub
# 9  -79.378937               2           Coffee Shop        Clothing Store
# 15 -79.375418               2           Coffee Shop                  Café
# 19 -79.293031               0     Health Food Store                 Trail
# 20 -79.373306               2           Coffee Shop                Bakery
#
#    3rd Most Common Venue 4th Most Common Venue      5th Most Common Venue  \
# ...

# %% [markdown]
# Visualization

# %%
# create map
map_clusters = folium.Map(location=[lat, long], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# Examine Clusters

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1]+ list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 19     East Toronto               0     Health Food Store
# 68  Central Toronto               0                 Trail
# 83  Central Toronto               0                   Gym
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 19                 Trail                   Pub             Wine Shop
# 68    Mexican Restaurant         Jewelry Store      Sushi Restaurant
# 83          Tennis Court                 Trail            Restaurant
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 19            Donut Shop   Distribution Center              Dive Bar
# 68             Wine Shop        Discount Store  Ethiopian Restaurant
# 83             Wine Shop      Doner Restaurant        Discount Store
#
#    8th Most Common Venue 9th Most Common Venue       10th Most Common Venue
# 19               Dog Run      Doner Restaurant  Eastern European Restaurant
# ...

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1]+ list(range(5, toronto_merged.shape[1]))]]
# Out:
#                   Borough  Cluster Labels 1st Most Common Venue  \
# 35  East YorkEast Toronto               1                  Park
# 91       Downtown Toronto               1                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 35     Convenience Store             Wine Shop        Discount Store
# 91            Playground                 Trail             Wine Shop
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 35    Falafel Restaurant           Event Space  Ethiopian Restaurant
# 91            Donut Shop        Discount Store   Distribution Center
#
#    8th Most Common Venue 9th Most Common Venue       10th Most Common Venue
# 35           Escape Room     Electronics Store  Eastern European Restaurant
# 91              Dive Bar               Dog Run             Doner Restaurant

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1]+ list(range(5, toronto_merged.shape[1]))]]
# Out:
#                                                Borough  Cluster Labels  \
# 2                                     Downtown Toronto               2
# 9                                     Downtown Toronto               2
# 15                                    Downtown Toronto               2
# 20                                    Downtown Toronto               2
# 24                                    Downtown Toronto               2
# 25                                    Downtown Toronto               2
# 30                                    Downtown Toronto               2
# 31                                        West Toronto               2
# 36                                    Downtown Toronto               2
# 37                                        West Toronto               2
# 41                                        East Toronto               2
# 42                                    Downtown Toronto               2
# ...

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1]+ list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 61  Central Toronto               3                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 61           Swim School              Bus Line             Wine Shop
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 61        Discount Store           Event Space  Ethiopian Restaurant
#
#    8th Most Common Venue 9th Most Common Venue       10th Most Common Venue
# 61           Escape Room     Electronics Store  Eastern European Restaurant

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1]+ list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 62  Central Toronto               4                Garden
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 62          Home Service                 Diner    Falafel Restaurant
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 62           Event Space  Ethiopian Restaurant           Escape Room
#
#    8th Most Common Venue        9th Most Common Venue 10th Most Common Venue
# 62     Electronics Store  Eastern European Restaurant    Dumpling Restaurant
